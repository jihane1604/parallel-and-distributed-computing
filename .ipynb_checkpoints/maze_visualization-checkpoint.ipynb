# %% [markdown]
# # Maze Visualization Demo
#
# This notebook demonstrates the visualization capabilities of the maze runner game using the visualization utilities from the project.

# %%
pip install matplotlib numpy pandas
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /home/student/anaconda3/envs/parallel/lib/python3.12/site-packages (2.0.1)
# Requirement already satisfied: pandas in /home/student/anaconda3/envs/parallel/lib/python3.12/site-packages (2.2.3)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.57.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (102 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: packaging>=20.0 in /home/student/anaconda3/envs/parallel/lib/python3.12/site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-11.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/student/anaconda3/envs/parallel/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/student/anaconda3/envs/parallel/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/student/anaconda3/envs/parallel/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/student/anaconda3/envs/parallel/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
# Using cached contourpy-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.57.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
# Using cached kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
# Using cached pillow-11.1.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.57.0 kiwisolver-1.4.8 matplotlib-3.10.1 pillow-11.1.0 pyparsing-3.2.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import pygame
import time
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Import our maze game modules
from src.maze import create_maze
from src.visualization import visualize_maze, JupyterExplorer
from src.explorer import Explorer
from src.constants import WINDOW_SIZE
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.2)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ## Initialize Pygame for Jupyter
#
# We need to initialize Pygame in a way that works with Jupyter notebooks.

# %%
# Initialize Pygame
pygame.init()
screen = pygame.display.set_mode((WINDOW_SIZE, WINDOW_SIZE))
pygame.display.set_caption("Maze Explorer - Jupyter Visualization")

# %% [markdown]
# ## Create and Visualize a Random Maze
#
# Let's create a random maze and visualize it using the visualization utilities.

# %%
# Create and visualize a random maze
maze = create_maze(30, 30, "random")
visualize_maze(maze, screen)

# %% [markdown]
# ## Animated Maze Solving
#
# Let's use the JupyterExplorer to solve the maze with animation.

# %%
# Create maze and explorer
maze = create_maze(30, 30, "random")
explorer = JupyterExplorer(maze, screen)

# Run the explorer
time_taken, moves = explorer.solve()
print(f"Maze solved in {time_taken:.2f} seconds")
print(f"Number of moves: {len(moves)}")
# Out:
# === Maze Exploration Statistics ===
# Total time taken: 10.31 seconds
# Total moves made: 56
# Number of backtrack operations: 0
# Average moves per second: 5.43
# ==================================
#
# Maze solved in 10.31 seconds
# Number of moves: 56

# %% [markdown]
# ## Compare Different Maze Types
#
# Let's compare the visualization of random and static mazes.

# %%
# Create and visualize a random maze
random_maze = create_maze(30, 30, "random")
print("Random Maze:")
visualize_maze(random_maze, screen)

# Create and visualize a static maze
static_maze = create_maze(30, 30, "static")
print("Static Maze:")
visualize_maze(static_maze, screen)
# Out:
# Random Maze:
# Static Maze:

# %% [markdown]
# ## Performance Analysis
#
# Let's analyze the performance of the automated explorer on different maze types.

# %%
def run_exploration(maze_type, width, height):
    maze = create_maze(width, height, maze_type)
    explorer = Explorer(maze, visualize=False)
    start_time = time.time()
    time_taken, moves = explorer.solve()
    return {
        'maze_type': maze_type,
        'time_taken': time_taken,
        'moves': len(moves),
        'moves_per_second': len(moves) / time_taken
    }

# Run multiple explorations
results = []
for maze_type in ['random', 'static']:
    for _ in range(3):  # Run each type 3 times
        result = run_exploration(maze_type, 30, 30)
        results.append(result)
print("Simulation Done")
# Display results
df = pd.DataFrame(results)
print("Exploration Results:")
print(df.groupby('maze_type').mean())
# Out:
# === Maze Exploration Statistics ===
# Total time taken: 0.00 seconds
# Total moves made: 80
# Number of backtrack operations: 0
# Average moves per second: 503064.95
# ==================================
#
#
# === Maze Exploration Statistics ===
# Total time taken: 0.00 seconds
# Total moves made: 182
# Number of backtrack operations: 0
# Average moves per second: 764127.46
# ==================================
#
#
# === Maze Exploration Statistics ===
# Total time taken: 0.00 seconds
# Total moves made: 696
# Number of backtrack operations: 0
# Average moves per second: 413255.32
# ==================================
#
#
# === Maze Exploration Statistics ===
# Total time taken: 0.00 seconds
# Total moves made: 1279
# Number of backtrack operations: 0
# Average moves per second: 1011790.80
# ==================================
#
#
# === Maze Exploration Statistics ===
# Total time taken: 0.00 seconds
# Total moves made: 1279
# Number of backtrack operations: 0
# Average moves per second: 1304917.25
# ==================================
#
#
# === Maze Exploration Statistics ===
# Total time taken: 0.00 seconds
# Total moves made: 1279
# Number of backtrack operations: 0
# Average moves per second: 850565.22
# ==================================
#
# Simulation Done
# Exploration Results:
#            time_taken        moves  moves_per_second
# maze_type
# random       0.000694   319.333333      5.601492e+05
# static       0.001249  1279.000000      1.055758e+06

# %%
# Redefine maze_strings as well since everything was reset
path = [(11, 0), (11, 1), (12, 1), (13, 1), (14, 1), (15, 1), (16, 1), (17, 1), (18, 1), (19, 1), (20, 1), (21, 1), (22, 1), (23, 1), (24, 1), (24, 2), (24, 3), (25, 3), (26, 3), (27, 3), (28, 3), (29, 3), (29, 4), (29, 5), (30, 5), (31, 5), (32, 5), (33, 5), (34, 5), (35, 5), (36, 5), (37, 5), (38, 5), (38, 6), (38, 7), (37, 7), (36, 7), (35, 7), (35, 8), (35, 9), (35, 10), (35, 11), (35, 12), (35, 13), (35, 14), (35, 15), (36, 15), (37, 15), (38, 15), (39, 15), (40, 15), (41, 15), (41, 16), (41, 17), (41, 18), (41, 19), (40, 19), (39, 19), (38, 19), (38, 20), (38, 21), (38, 22), (38, 23), (38, 24), (38, 25), (37, 25), (36, 25), (35, 25), (35, 26), (35, 27), (35, 28), (35, 29), (35, 30), (34, 30), (33, 30), (32, 30), (32, 31), (32, 32), (32, 33), (32, 34), (32, 35), (32, 36), (31, 36), (30, 36), (29, 36), (29, 35), (29, 34), (28, 34), (27, 34), (26, 34), (25, 34), (24, 34), (23, 34), (23, 35), (23, 36), (24, 36), (25, 36), (26, 36), (26, 37), (26, 38), (27, 38), (28, 38), (29, 38), (29, 39), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (23, 41), (23, 42), (23, 43), (23, 44), (23, 45), (23, 46), (22, 46), (21, 46), (20, 46), (19, 46), (18, 46), (17, 46), (16, 46), (15, 46), (14, 46), (13, 46), (13, 47)]
def visualize_path(path, name):
    maze_strings = [
        "11111111111011111111111111111111111111111111111111111111111111",
        "10000000010000000000000001011001000000000001001000000000000101",
        "10010011111111110011111001011011111111001001001001001111111101",
        "10010000000000000010001000000001011001001000000001000000000001",
        "11110010011111111110011110001011001011111111001001001111111111",
        "10000010000010000000000001011000000000000001001001000000000101",
        "10111111110010010010011111111011111111001001001111001111100101",
        "10010000010010010010000000001000001000001001001000001000000001",
        "10010010011110011110011111111011111011111111001111111111111101",
        "10010010010010010000001000001011001011000001000001001000000001",
        "11110011110010010011111111011111001011001111001001001111111101",
        "10000000010000010010000001011001000000001000001000000000100001",
        "11110011110010011110011111001011111011111111111001111111101111",
        "10000000000010000000000000000000000001000001000000000000100001",
        "10111111111111110011111011111111111011111001111001111111111101",
        "10010000000010000000001011000000001000000001000000001000000001",
        "10010011111110011111111001011011111011111001001111111111111101",
        "10000000000010000000001011001000001011001001000000000000000101",
        "11110011111111110010011111111001011111001001111001111111111111",
        "10000010000000000010000001011001011000000000000001000000000101",
        "10111110011111110010001011001011011111001001111001111000101101",
        "10010010000000010010001000001011000001001001001000000000101101",
        "11110011110011111111111111111001011111001111001111001111111101",
        "10000010010000010000001011000001000000000000000001000000000101",
        "11110010011111111110001011111111111111001001111111001111100101",
        "10000000000000000000000000000001000000001001001000000000100001",
        "10111111111110011111111011111111001011111001001001111111101111",
        "10011111111110011111110011111111001011111001001001111111001111",
        "10000010000010010000000000001000001011000000001001001000000001",
        "11110011110010010011111011111111111011111001111001001001111101",
        "10010000010010010010000000000001000000001001001000001000000101",
        "10111110010011111110001011111001011111111001001001111111111101",
        "10000010000000010000001000001000001011000001000001000000101101",
        "10111110011111111111111111111111001011111111111001001111100101",
        "10010010000000010000000000000001000000001000000000001000000001",
        "10010010011110011111111011111001011011111111111001111111100101",
        "10000000000010010000001000001000001000001000001000001000101101",
        "11111110011111110011111111011111111001001111001111111000101111",
        "10000010000010010000000001000000001011001000000000000000101101",
        "10010010010010010011111111111001011111111111111001111001111101",
        "10010000010000000010000000000001000000001001001000001000000001",
        "11111111111111110011111011111011111111111001001001001111111101",
        "10010000000000010010000001000001000000001000000001000000101101",
        "10010011111111110010001011111111001011001001001111111111100101",
        "10010010010000010010001011000001011001001001000001000000101101",
        "10010010010011111111111001011011111011111001001001001000101101",
        "10000000000000000000000000001000000000000001001001001000000001",
        "11111111111110111111111111111111111111111111111111111111111111"
    ]
    
    # Convert to numpy array and get dimensions
    maze_array = np.array([[int(cell) for cell in row] for row in maze_strings])
    height, width = maze_array.shape
    
    # Recreate the image
    image = np.zeros((height, width, 3), dtype=np.uint8)
    
    # Walls = black, Free space = white
    for y in range(height):
        for x in range(width):
            image[y, x] = [0, 0, 0] if maze_array[y, x] == 1 else [255, 255, 255]
    
    # Color the path red
    for x, y in path:
        image[y, x] = [255, 0, 0]
    
    # Plotting
    plt.figure(figsize=(12, 10))
    plt.imshow(image)
    plt.title(f"Maze Path Traversd by {name} Algorithm")
    plt.axis("off")
    plt.show()

visualize_path(path, "Flood Fill")

# %%
astar_path = [(11, 0), (11, 1), (12, 1), (13, 1), (14, 1), (15, 1), (16, 1), (17, 1), (18, 1), (19, 1), (20, 1), (21, 1), (22, 1), (23, 1), (23, 2), (23, 3), (24, 3), (25, 3), (26, 3), (27, 3), (28, 3), (29, 3), (29, 4), (29, 5), (30, 5), (31, 5), (32, 5), (33, 5), (34, 5), (35, 5), (36, 5), (37, 5), (38, 5), (38, 6), (38, 7), (37, 7), (36, 7), (35, 7), (35, 8), (35, 9), (35, 10), (35, 11), (35, 12), (35, 13), (35, 14), (35, 15), (36, 15), (37, 15), (38, 15), (39, 15), (40, 15), (41, 15), (41, 16), (41, 17), (41, 18), (41, 19), (40, 19), (39, 19), (38, 19), (38, 20), (38, 21), (38, 22), (38, 23), (38, 24), (38, 25), (37, 25), (36, 25), (35, 25), (35, 26), (35, 27), (35, 28), (35, 29), (35, 30), (34, 30), (33, 30), (32, 30), (32, 31), (32, 32), (32, 33), (32, 34), (32, 35), (32, 36), (31, 36), (30, 36), (29, 36), (29, 35), (29, 34), (28, 34), (27, 34), (26, 34), (25, 34), (24, 34), (23, 34), (23, 35), (23, 36), (24, 36), (25, 36), (26, 36), (26, 37), (26, 38), (27, 38), (28, 38), (29, 38), (29, 39), (29, 40), (28, 40), (27, 40), (26, 40), (25, 40), (24, 40), (23, 40), (23, 41), (23, 42), (23, 43), (23, 44), (23, 45), (23, 46), (22, 46), (21, 46), (20, 46), (19, 46), (18, 46), (17, 46), (16, 46), (15, 46), (14, 46), (13, 46), (13, 47)]
visualize_path(astar_path, "A*")
